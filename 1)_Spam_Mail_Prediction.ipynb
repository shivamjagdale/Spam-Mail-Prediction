# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_csv("/content/drive/MyDrive/ML Datasets/Mail-Data.csv")
df = pd.DataFrame(a)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
df = df.fillna(" ")

# %%
df["Category"].value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df["Category"] = df["Category"].replace("spam", 0)
df["Category"] = df["Category"].replace("ham", 1)
# Out:
# <ipython-input-14-412e375f436b>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Category"] = df["Category"].replace("ham", 1)

# %%
df
# Out:
#       Category                                            Message
# 0            1  Go until jurong point, crazy.. Available only ...
# 1            1                      Ok lar... Joking wif u oni...
# 2            0  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            1  U dun say so early hor... U c already then say...
# 4            1  Nah I don't think he goes to usf, he lives aro...
# ...        ...                                                ...
# 5567         0  This is the 2nd time we have tried 2 contact u...
# 5568         1               Will ü b going to esplanade fr home?
# 5569         1  Pity, * was in mood for that. So...any other s...
# 5570         1  The guy did some bitching but I acted like i'd...
# 5571         1                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X = df["Message"]

# %%
Y = df["Category"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=2, stratify=Y, shuffle=True)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (5572,) (4457,) (1115,)

# %%
vectorizer = TfidfVectorizer()

# %%
vectorizer.fit(X_train)
# Out:
# TfidfVectorizer()

# %%
X_train = vectorizer.transform(X_train)

# %%
X_test = vectorizer.transform(X_test)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
X_train_prediction = model.predict(X_train)
X_train_acc = accuracy_score(X_train_prediction, Y_train)
print(X_train_acc)
# Out:
# 0.9741978909580435

# %%
X_test_prediction = model.predict(X_test)
X_test_acc = accuracy_score(X_test_prediction, Y_test)
print(X_test_acc)
# Out:
# 0.9775784753363229

# %%
#

# %%
input_data = ["Short But Cute: ""Be a good person, but dont try to prove it.."" .Gud noon...."]

# %%
vect = vectorizer.transform(input_data)

# %%
prediction = model.predict(vect)

# %%
print(prediction)
# Out:
# [1]

# %%
if prediction[0]==1:
  print("The email is real")
else:
  print("The email is fake")
# Out:
# The email is real

# %% [markdown]
# # **Saving Models and Vectorizer**

# %%
import joblib
joblib.dump(model, "spam_model.pkl")
# Out:
# ['spam_model.pkl']

# %%
joblib.dump(vectorizer, "vectorizer_model.pkl")
# Out:
# ['vectorizer_model.pkl']

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 26.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.6/322.6 kB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 104.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.1 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
import joblib

# Load the saved model and vectorizer
model = joblib.load("spam_model.pkl")         # Your trained Logistic Regression model
vectorizer = joblib.load("vectorizer_model.pkl")  # Your saved vectorizer (e.g., TfidfVectorizer or CountVectorizer)

# Define prediction function
def predict_email(text):
    text_vector = vectorizer.transform([text])  # Convert text to vector
    prediction = model.predict(text_vector)[0]  # Predict category (0 or 1)

    if prediction == 1:
        return "✅ Real Email"
    else:
        return "❌ Fake Email"

# Gradio Interface
gr.Interface(
    fn=predict_email,
    inputs=gr.Textbox(lines=5, placeholder="Enter email message here...", label="Email Message"),
    outputs=gr.Text(label="Prediction"),
    title="Email Spam Detector",
    description="Enter an email message to check if it's real or fake."
).launch()
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://31b38fc572c7937ba9.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://31b38fc572c7937ba9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
